# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/blob/main/Classifier/LoadData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_1k.txt
# Out:
# --2024-01-29 10:59:50--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_1k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12384 (12K) [text/plain]
# Saving to: ‘jrfid_data_1k.txt’
#
# jrfid_data_1k.txt   100%[===================>]  12.09K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:50 (85.8 MB/s) - ‘jrfid_data_1k.txt’ saved [12384/12384]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_2k.txt
# Out:
# --2024-01-29 10:59:50--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_2k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13008 (13K) [text/plain]
# Saving to: ‘jrfid_data_2k.txt’
#
# jrfid_data_2k.txt   100%[===================>]  12.70K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:50 (101 MB/s) - ‘jrfid_data_2k.txt’ saved [13008/13008]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_3k.txt
# Out:
# --2024-01-29 10:59:50--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_3k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15120 (15K) [text/plain]
# Saving to: ‘jrfid_data_3k.txt’
#
# jrfid_data_3k.txt   100%[===================>]  14.77K  --.-KB/s    in 0.001s
#
# 2024-01-29 10:59:51 (27.5 MB/s) - ‘jrfid_data_3k.txt’ saved [15120/15120]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_4k.txt
# Out:
# --2024-01-29 10:59:51--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_4k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14304 (14K) [text/plain]
# Saving to: ‘jrfid_data_4k.txt’
#
# jrfid_data_4k.txt   100%[===================>]  13.97K  --.-KB/s    in 0.001s
#
# 2024-01-29 10:59:51 (20.3 MB/s) - ‘jrfid_data_4k.txt’ saved [14304/14304]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_6_8k.txt
# Out:
# --2024-01-29 10:59:51--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_6_8k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9360 (9.1K) [text/plain]
# Saving to: ‘jrfid_data_6_8k.txt’
#
# jrfid_data_6_8k.txt 100%[===================>]   9.14K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:51 (89.9 MB/s) - ‘jrfid_data_6_8k.txt’ saved [9360/9360]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_0_22k.txt
# Out:
# --2024-01-29 10:59:51--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_0_22k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13536 (13K) [text/plain]
# Saving to: ‘jrfid_data_0_22k.txt’
#
# jrfid_data_0_22k.tx 100%[===================>]  13.22K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:51 (28.2 MB/s) - ‘jrfid_data_0_22k.txt’ saved [13536/13536]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_22k.txt
# Out:
# --2024-01-29 10:59:51--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_22k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14208 (14K) [text/plain]
# Saving to: ‘jrfid_data_22k.txt’
#
# jrfid_data_22k.txt  100%[===================>]  13.88K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:51 (29.0 MB/s) - ‘jrfid_data_22k.txt’ saved [14208/14208]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_120k_nominal.txt
# Out:
# --2024-01-29 10:59:51--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_120k_nominal.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8160 (8.0K) [text/plain]
# Saving to: ‘jrfid_data_120k_nominal.txt’
#
# jrfid_data_120k_nom 100%[===================>]   7.97K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:52 (76.2 MB/s) - ‘jrfid_data_120k_nominal.txt’ saved [8160/8160]

# %%
# !wget https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_100k.txt
# Out:
# --2024-01-29 10:59:52--  https://raw.githubusercontent.com/marco-milanesi/FlybackConverter-FPGA-based-Digital-Twin/main/Classifier/Dataset/jrfid_data_100k.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10560 (10K) [text/plain]
# Saving to: ‘jrfid_data_100k.txt’
#
# jrfid_data_100k.txt 100%[===================>]  10.31K  --.-KB/s    in 0s
#
# 2024-01-29 10:59:52 (96.5 MB/s) - ‘jrfid_data_100k.txt’ saved [10560/10560]

# %% [markdown]
# ## Import Packages

# %%
import os
import pandas as pd
import numpy as np
import statistics
import glob
from numpy import mean, absolute
from natsort import natsorted

# %% [markdown]
# ## Load Test Data

# %%
import pandas as pd

def process_file(file_path, R):
    # Open the file in read mode
    with open(file_path, 'r') as file:
        # Read lines into a list
        lines = file.readlines()

        # Extract the first two columns from each line
        first_two_columns = [(line.split()[0], line.split()[1]) for line in lines]

    filtered_list = [(tup[0].lstrip('0'), tup[1].lstrip('0')) for tup in first_two_columns if tup[0] != '00000']

    dataset = {}

    for key, value in filtered_list:
        key = int(key)
        value = int(value)

        if key not in dataset:
            dataset[key] = []

        dataset[key].append(value)

    # Create a DataFrame
    df_test = pd.DataFrame(list(dataset.items()), columns=['DC', 'Voltage'])

    # Add a constant label with the specified value at position 0
    df_test.insert(0, 'R', R)

    return df_test

# %%
file_path = 'jrfid_data_1k.txt'
R = 0.1
df1 = process_file(file_path, R)

file_path = 'jrfid_data_2k.txt'
R = 0.2
df2 = process_file(file_path, R)

file_path = 'jrfid_data_3k.txt'
R = 0.3
df3 = process_file(file_path, R)

file_path = 'jrfid_data_4k.txt'
R = 0.4
df4 = process_file(file_path, R)

file_path = 'jrfid_data_6_8k.txt'
R = 0.68
df5 = process_file(file_path, R)

file_path = 'jrfid_data_22k.txt'
R = 2.2
df6 = process_file(file_path, R)

file_path = 'jrfid_data_100k.txt'
R = 10
df7 = process_file(file_path, R)

file_path = 'jrfid_data_120k_nominal.txt'
R = 12
df8 = process_file(file_path, R)

test_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)

test_df['DC'] = test_df['DC'] / 249
test_df['Voltage'] = test_df['Voltage'].apply(lambda x: [v/255 for v in x])

# %% [markdown]
# ## Extract test features

# %%
import numpy as np

def calculate_features(data):
    mean_voltage = np.mean(data)
    maximum_voltage = np.max(data)
    range_voltage = np.ptp(data)  # Peak-to-peak distance (max - min)
    variance_voltage = np.var(data)
    median_voltage = np.median(data)
    first_quartile_voltage = np.percentile(data, 25)
    third_quartile_voltage = np.percentile(data, 75)
    absolute_mean_deviation_voltage = np.mean(np.abs(data - np.mean(data)))
    mean_absolute_local_derivative_voltage = np.mean(np.abs(np.diff(data)))

    features = [mean_voltage, maximum_voltage, range_voltage, variance_voltage, median_voltage,
                first_quartile_voltage, third_quartile_voltage, absolute_mean_deviation_voltage,
                mean_absolute_local_derivative_voltage]

    return features

# %%
import numpy as np
import pandas as pd

# Assuming your dataset is stored in a DataFrame named 'df'
# Replace this with your actual dataset loading mechanism

def calculate_features(data):
    mean_voltage = np.mean(data)
    maximum_voltage = np.max(data)
    range_voltage = np.ptp(data)
    variance_voltage = np.var(data)
    median_voltage = np.median(data)
    first_quartile_voltage = np.percentile(data, 25)
    third_quartile_voltage = np.percentile(data, 75)
    absolute_mean_deviation_voltage = np.mean(np.abs(data - np.mean(data)))
    mean_absolute_local_derivative_voltage = np.mean(np.abs(np.diff(data)))

    features = [mean_voltage, maximum_voltage, range_voltage, variance_voltage, median_voltage,
                first_quartile_voltage, third_quartile_voltage, absolute_mean_deviation_voltage,
                mean_absolute_local_derivative_voltage]

    return features

# Assuming 'df' is your DataFrame
# Create empty columns for each feature
feature_columns = ['mean voltage', 'maximum voltage', 'range voltage', 'variance voltage',
                   'median voltage', 'First Quartile Voltage', 'Third Quartile Voltage',
                   'Absolute Mean Deviation Voltage', 'Mean Absolute Local Derivative Voltage']

# Iterate over rows, calculate features, and update DataFrame
for index, row in test_df.iterrows():
    voltage_values = np.array(row['Voltage'])
    features = calculate_features(voltage_values)

    # Unpack the list and assign each feature to the corresponding column
    for i, col in enumerate(feature_columns):
        test_df.at[index, col] = features[i]

# Drop the original 'Voltage' column
test_df.drop('Voltage', axis=1, inplace=True)

test_df
test_df['DC'] = np.floor(test_df['DC']*100)
test_df['R'] =  np.floor(test_df['R']*10)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
test_df = test_df[test_df['DC'] <= 80]
test_df
# Out:
#         R    DC  mean voltage  maximum voltage  range voltage  \
# 2     1.0  75.0      0.050740         0.054902       0.007843
# 4     1.0  69.0      0.039636         0.043137       0.003922
# 7     2.0  75.0      0.074661         0.113725       0.074510
# 8     2.0  69.0      0.058824         0.058824       0.000000
# 12    3.0  59.0      0.109804         0.109804       0.000000
# 13    3.0  75.0      0.087255         0.098039       0.011765
# 16    3.0  69.0      0.067617         0.070588       0.027451
# 19    4.0  75.0      0.095544         0.101961       0.007843
# 22    4.0  69.0      0.077087         0.113725       0.074510
# 24    6.0  75.0      0.106839         0.125490       0.019608
# 27    6.0  69.0      0.086129         0.098039       0.015686
# 29   22.0  75.0      0.122421         0.137255       0.015686
# 32   22.0  69.0      0.099278         0.109804       0.031373
# 35  100.0  69.0      0.106863         0.125490       0.019608
# 37  100.0  75.0      0.129942         0.152941       0.027451
# 41  120.0  69.0      0.106667         0.113725       0.007843
# 42  120.0  75.0      0.130824         0.156863       0.027451
#
#     variance voltage  median voltage  First Quartile Voltage  \
# 2       3.394715e-06        0.050980                0.050980
# 4       1.471177e-06        0.039216                0.039216
# 7       2.099557e-04        0.074510                0.070588
# 8       1.925930e-34        0.058824                0.058824
# 12      0.000000e+00        0.109804                0.109804
# 13      4.934000e-06        0.086275                0.086275
# 16      4.197015e-05        0.070588                0.066667
# 19      4.956771e-06        0.094118                0.094118
# 22      2.011911e-04        0.074510                0.074510
# 24      1.033785e-05        0.105882                0.105882
# 27      7.383464e-06        0.086275                0.086275
# 29      5.736730e-06        0.121569                0.121569
# 32      1.789212e-05        0.098039                0.098039
# 35      1.266995e-05        0.105882                0.105882
# 37      1.592914e-05        0.129412                0.129412
# 41      3.998462e-06        0.105882                0.105882
# 42      2.937947e-05        0.129412                0.129412
#
#     Third Quartile Voltage  Absolute Mean Deviation Voltage  \
# 2                 0.050980                     1.051849e-03
# 4                 0.039216                     7.503001e-04
# 7                 0.074510                     6.903353e-03
# 8                 0.058824                     1.387779e-17
# 12                0.109804                     0.000000e+00
# 13                0.086275                     1.568627e-03
# 16                0.070588                     3.601073e-03
# 19                0.098039                     1.944579e-03
# 22                0.078431                     7.126050e-03
# 24                0.105882                     1.633015e-03
# 27                0.086275                     1.118911e-03
# 29                0.121569                     1.433213e-03
# 32                0.101961                     2.531096e-03
# 35                0.105882                     1.782531e-03
# 37                0.129412                     1.426546e-03
# 41                0.105882                     1.333333e-03
# 42                0.129412                     2.484706e-03
#
#     Mean Absolute Local Derivative Voltage
# 2                                 0.001797
# 4                                 0.000726
# 7                                 0.013226
# 8                                 0.000000
# 12                                     NaN
# 13                                0.001662
# 16                                0.004289
# 19                                0.002554
# 22                                0.012572
# 24                                0.001863
# 27                                0.001659
# 29                                0.001384
# 32                                0.003392
# 35                                0.001186
# 37                                0.001089
# 41                                0.000826
# 42                                0.001471

# %%
test_df.to_csv('TestData58_80.csv', index=False)
